# %% [markdown]
# ## This is a model based on the first baseline model  classiconvNet with some batch normalization and without integrating the early stopping that gaves better result than the first one but still facing the overfitting.

# %%
### Importing librairies and packages
import keras
import keras.utils
import matplotlib.pyplot as plt
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, Dropout, Activation, MaxPool2D, Flatten
from keras.layers.convolutional import Conv2D
from tensorflow.keras.layers import (
    BatchNormalization, MaxPooling2D)
from tensorflow.keras.optimizers import SGD
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = '/content/drive/MyDrive/15-Scene Image Dataset/15-Scene/'

one_hot_lookup = np.eye(15) # 15 classes

dataset_x = []
dataset_y = []

for category in sorted(os.listdir(DATASET_PATH)):
    print('loading category: '+str(int(category)))
    for fname in os.listdir(DATASET_PATH+category):
        img = cv2.imread(DATASET_PATH+category+'/'+fname, 2)
        img = cv2.resize(img, (224,224))
        dataset_x.append(np.reshape(img, [224,224,1]))
        dataset_y.append(np.reshape(one_hot_lookup[int(category)], [15]))

dataset_x = np.array(dataset_x)
dataset_y = np.array(dataset_y)
####shuffling the data
p = np.random.permutation(len(dataset_x))
dataset_x = dataset_x[p]
dataset_y = dataset_y[p]
        
X_test = dataset_x[:int(len(dataset_x)/10)]
Y_test = dataset_y[:int(len(dataset_x)/10)]
X_train = dataset_x[int(len(dataset_x)/10):]
Y_train = dataset_y[int(len(dataset_x)/10):]
# Out:
# loading category: 0
# loading category: 1
# loading category: 2
# loading category: 3
# loading category: 4
# loading category: 5
# loading category: 6
# loading category: 7
# loading category: 8
# loading category: 9
# loading category: 10
# loading category: 11
# loading category: 12
# loading category: 13
# loading category: 14

# %%
##Model architecture 

from keras.backend import learning_phase
batch_size = 128
num_classes = 15
epochs = 100
img_rows, img_cols = X_train.shape[1],X_train.shape[2]
input_shape = (img_rows, img_cols, 1)
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu', input_shape = input_shape))
model.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
model.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                     activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1024, activation = "relu"))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(512, activation = "relu"))
model.add(Dropout(0.4))
model.add(Dense(15, activation = "softmax"))
# Define the optimizer
#optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
#callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)
optimizer = Adam(learning_rate=0.001, decay=1e-6)
model.compile(optimizer = optimizer , loss = "categorical_crossentropy", metrics=["accuracy"])
model.summary()
    
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), batch_size= batch_size, epochs=epochs)
score = model.evaluate(X_test,Y_test, verbose=1)
print('\nAccuracy:', score[1])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      320
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  batch_normalization (BatchN  (None, 112, 112, 32)     128
#  ormalization)
#
#  dropout (Dropout)           (None, 112, 112, 32)      0
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 64)      18496
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 56, 56, 64)       256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 56, 56, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 86)        49622
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 86)        66650
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 86)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 28, 28, 86)       344
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 28, 28, 86)        0
#
#  flatten (Flatten)           (None, 67424)             0
#
#  dense (Dense)               (None, 1024)              69043200
#
#  batch_normalization_3 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 15)                7695
#
# =================================================================
# Total params: 69,761,783
# Trainable params: 69,759,371
# Non-trainable params: 2,412
# _________________________________________________________________
# Epoch 1/100
# 32/32 [==============================] - 81s 2s/step - loss: 2.6520 - accuracy: 0.3094 - val_loss: 10.8208 - val_accuracy: 0.0781
# Epoch 2/100
# 32/32 [==============================] - 40s 1s/step - loss: 1.4967 - accuracy: 0.5502 - val_loss: 2.5774 - val_accuracy: 0.2969
# Epoch 3/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.9430 - accuracy: 0.6941 - val_loss: 2.6866 - val_accuracy: 0.3638
# Epoch 4/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5376 - accuracy: 0.8229 - val_loss: 2.4281 - val_accuracy: 0.3929
# Epoch 5/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.3136 - accuracy: 0.8942 - val_loss: 2.3710 - val_accuracy: 0.4107
# Epoch 6/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.1918 - accuracy: 0.9388 - val_loss: 1.3471 - val_accuracy: 0.6116
# Epoch 7/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.1036 - accuracy: 0.9680 - val_loss: 1.3508 - val_accuracy: 0.6317
# Epoch 8/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0761 - accuracy: 0.9740 - val_loss: 2.9053 - val_accuracy: 0.4487
# Epoch 9/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0634 - accuracy: 0.9784 - val_loss: 1.6749 - val_accuracy: 0.6384
# Epoch 10/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0388 - accuracy: 0.9871 - val_loss: 2.4657 - val_accuracy: 0.5290
# Epoch 11/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0308 - accuracy: 0.9911 - val_loss: 1.9679 - val_accuracy: 0.5982
# Epoch 12/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0331 - accuracy: 0.9889 - val_loss: 4.4983 - val_accuracy: 0.3504
# Epoch 13/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0206 - accuracy: 0.9941 - val_loss: 1.4642 - val_accuracy: 0.6808
# Epoch 14/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0217 - accuracy: 0.9938 - val_loss: 1.5556 - val_accuracy: 0.6183
# Epoch 15/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 1.6270 - val_accuracy: 0.6607
# Epoch 16/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0205 - accuracy: 0.9946 - val_loss: 1.4856 - val_accuracy: 0.6897
# Epoch 17/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 1.3496 - val_accuracy: 0.7299
# Epoch 18/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0179 - accuracy: 0.9958 - val_loss: 1.2511 - val_accuracy: 0.7299
# Epoch 19/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0314 - accuracy: 0.9918 - val_loss: 1.6010 - val_accuracy: 0.6786
# Epoch 20/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 1.9802 - val_accuracy: 0.6228
# Epoch 21/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0169 - accuracy: 0.9960 - val_loss: 1.6763 - val_accuracy: 0.7098
# Epoch 22/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0200 - accuracy: 0.9946 - val_loss: 1.7382 - val_accuracy: 0.6786
# Epoch 23/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0193 - accuracy: 0.9950 - val_loss: 2.4123 - val_accuracy: 0.5737
# Epoch 24/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0206 - accuracy: 0.9948 - val_loss: 1.8430 - val_accuracy: 0.6228
# Epoch 25/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0165 - accuracy: 0.9936 - val_loss: 1.7939 - val_accuracy: 0.6674
# Epoch 26/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0224 - accuracy: 0.9948 - val_loss: 2.9876 - val_accuracy: 0.5960
# Epoch 27/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0256 - accuracy: 0.9933 - val_loss: 2.8449 - val_accuracy: 0.5670
# Epoch 28/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0347 - accuracy: 0.9881 - val_loss: 12.7172 - val_accuracy: 0.2031
# Epoch 29/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0392 - accuracy: 0.9889 - val_loss: 2.2266 - val_accuracy: 0.6362
# Epoch 30/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0379 - accuracy: 0.9906 - val_loss: 2.3008 - val_accuracy: 0.6004
# Epoch 31/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0407 - accuracy: 0.9891 - val_loss: 2.7357 - val_accuracy: 0.6250
# Epoch 32/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0245 - accuracy: 0.9943 - val_loss: 1.9077 - val_accuracy: 0.6451
# Epoch 33/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0249 - accuracy: 0.9943 - val_loss: 2.8514 - val_accuracy: 0.5513
# Epoch 34/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0389 - accuracy: 0.9898 - val_loss: 3.2813 - val_accuracy: 0.5625
# Epoch 35/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0381 - accuracy: 0.9889 - val_loss: 2.9751 - val_accuracy: 0.5871
# Epoch 36/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0390 - accuracy: 0.9874 - val_loss: 2.1787 - val_accuracy: 0.6429
# Epoch 37/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0395 - accuracy: 0.9874 - val_loss: 2.5027 - val_accuracy: 0.6272
# Epoch 38/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0261 - accuracy: 0.9901 - val_loss: 2.4667 - val_accuracy: 0.6629
# Epoch 39/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0186 - accuracy: 0.9928 - val_loss: 2.6494 - val_accuracy: 0.6562
# Epoch 40/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0284 - accuracy: 0.9913 - val_loss: 2.7898 - val_accuracy: 0.6161
# Epoch 41/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0429 - accuracy: 0.9891 - val_loss: 3.5997 - val_accuracy: 0.5246
# Epoch 42/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0319 - accuracy: 0.9903 - val_loss: 2.6730 - val_accuracy: 0.6696
# Epoch 43/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0359 - accuracy: 0.9876 - val_loss: 2.3238 - val_accuracy: 0.6540
# Epoch 44/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0315 - accuracy: 0.9903 - val_loss: 4.7491 - val_accuracy: 0.5402
# Epoch 45/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0265 - accuracy: 0.9918 - val_loss: 2.3357 - val_accuracy: 0.6295
# Epoch 46/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0379 - accuracy: 0.9884 - val_loss: 3.0691 - val_accuracy: 0.6228
# Epoch 47/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0333 - accuracy: 0.9916 - val_loss: 2.1033 - val_accuracy: 0.6518
# Epoch 48/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0144 - accuracy: 0.9958 - val_loss: 2.2412 - val_accuracy: 0.6763
# Epoch 49/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0218 - accuracy: 0.9928 - val_loss: 2.3280 - val_accuracy: 0.6205
# Epoch 50/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0339 - accuracy: 0.9889 - val_loss: 2.8651 - val_accuracy: 0.5647
# Epoch 51/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0253 - accuracy: 0.9923 - val_loss: 2.4597 - val_accuracy: 0.6496
# Epoch 52/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 2.1624 - val_accuracy: 0.6696
# Epoch 53/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0237 - accuracy: 0.9938 - val_loss: 2.4215 - val_accuracy: 0.6763
# Epoch 54/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0237 - accuracy: 0.9933 - val_loss: 2.4333 - val_accuracy: 0.6406
# Epoch 55/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0209 - accuracy: 0.9928 - val_loss: 3.7779 - val_accuracy: 0.6161
# Epoch 56/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 2.2564 - val_accuracy: 0.6741
# Epoch 57/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0162 - accuracy: 0.9960 - val_loss: 2.0018 - val_accuracy: 0.6786
# Epoch 58/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0253 - accuracy: 0.9926 - val_loss: 2.4142 - val_accuracy: 0.6540
# Epoch 59/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0255 - accuracy: 0.9936 - val_loss: 2.3976 - val_accuracy: 0.6116
# Epoch 60/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0160 - accuracy: 0.9955 - val_loss: 3.1405 - val_accuracy: 0.6116
# Epoch 61/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0193 - accuracy: 0.9938 - val_loss: 2.2784 - val_accuracy: 0.6473
# Epoch 62/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0168 - accuracy: 0.9958 - val_loss: 2.1945 - val_accuracy: 0.6763
# Epoch 63/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 2.3188 - val_accuracy: 0.6272
# Epoch 64/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0190 - accuracy: 0.9943 - val_loss: 2.6306 - val_accuracy: 0.6228
# Epoch 65/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0131 - accuracy: 0.9960 - val_loss: 1.9853 - val_accuracy: 0.6786
# Epoch 66/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 2.3829 - val_accuracy: 0.6741
# Epoch 67/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0123 - accuracy: 0.9963 - val_loss: 6.4557 - val_accuracy: 0.5089
# Epoch 68/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0201 - accuracy: 0.9941 - val_loss: 2.7954 - val_accuracy: 0.6138
# Epoch 69/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0143 - accuracy: 0.9948 - val_loss: 2.6282 - val_accuracy: 0.6562
# Epoch 70/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0119 - accuracy: 0.9955 - val_loss: 2.6331 - val_accuracy: 0.5804
# Epoch 71/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0172 - accuracy: 0.9941 - val_loss: 3.0802 - val_accuracy: 0.6183
# Epoch 72/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0146 - accuracy: 0.9960 - val_loss: 2.7493 - val_accuracy: 0.6272
# Epoch 73/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0102 - accuracy: 0.9960 - val_loss: 3.3554 - val_accuracy: 0.6161
# Epoch 74/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0132 - accuracy: 0.9968 - val_loss: 2.3366 - val_accuracy: 0.6719
# Epoch 75/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0161 - accuracy: 0.9960 - val_loss: 2.2753 - val_accuracy: 0.6451
# Epoch 76/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 2.8270 - val_accuracy: 0.6384
# Epoch 77/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0070 - accuracy: 0.9973 - val_loss: 2.1308 - val_accuracy: 0.7009
# Epoch 78/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0179 - accuracy: 0.9955 - val_loss: 2.8170 - val_accuracy: 0.6496
# Epoch 79/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0172 - accuracy: 0.9958 - val_loss: 3.5017 - val_accuracy: 0.5536
# Epoch 80/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0327 - accuracy: 0.9908 - val_loss: 2.7428 - val_accuracy: 0.6339
# Epoch 81/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0282 - accuracy: 0.9928 - val_loss: 2.7776 - val_accuracy: 0.6094
# Epoch 82/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0233 - accuracy: 0.9928 - val_loss: 2.8034 - val_accuracy: 0.6183
# Epoch 83/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0229 - accuracy: 0.9913 - val_loss: 3.5287 - val_accuracy: 0.5580
# Epoch 84/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0265 - accuracy: 0.9928 - val_loss: 3.0001 - val_accuracy: 0.5982
# Epoch 85/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0314 - accuracy: 0.9908 - val_loss: 2.6976 - val_accuracy: 0.6518
# Epoch 86/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0251 - accuracy: 0.9916 - val_loss: 2.6332 - val_accuracy: 0.5982
# Epoch 87/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0210 - accuracy: 0.9946 - val_loss: 3.0201 - val_accuracy: 0.6027
# Epoch 88/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0155 - accuracy: 0.9936 - val_loss: 2.3249 - val_accuracy: 0.6496
# Epoch 89/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0196 - accuracy: 0.9946 - val_loss: 3.0648 - val_accuracy: 0.6071
# Epoch 90/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0288 - accuracy: 0.9928 - val_loss: 3.1125 - val_accuracy: 0.6339
# Epoch 91/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0238 - accuracy: 0.9913 - val_loss: 10.8871 - val_accuracy: 0.2567
# Epoch 92/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0227 - accuracy: 0.9938 - val_loss: 3.2943 - val_accuracy: 0.5804
# Epoch 93/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0228 - accuracy: 0.9948 - val_loss: 3.2347 - val_accuracy: 0.6362
# Epoch 94/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0184 - accuracy: 0.9946 - val_loss: 2.3707 - val_accuracy: 0.6741
# Epoch 95/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0370 - accuracy: 0.9921 - val_loss: 3.4768 - val_accuracy: 0.6250
# Epoch 96/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0180 - accuracy: 0.9958 - val_loss: 4.4955 - val_accuracy: 0.6205
# Epoch 97/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0290 - accuracy: 0.9916 - val_loss: 3.3614 - val_accuracy: 0.6138
# Epoch 98/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0268 - accuracy: 0.9926 - val_loss: 2.7213 - val_accuracy: 0.6406
# Epoch 99/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0334 - accuracy: 0.9911 - val_loss: 2.7494 - val_accuracy: 0.6518
# Epoch 100/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.0273 - accuracy: 0.9921 - val_loss: 2.7547 - val_accuracy: 0.6362
# 14/14 [==============================] - 4s 103ms/step - loss: 2.7547 - accuracy: 0.6362
#
# Accuracy: 0.6361607313156128

# %%
# Plot training & validation accuracy value

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
    
# Plot training & validation loss values

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
